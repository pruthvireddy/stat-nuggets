# %%
import pandas as pd
import numpy as np


N = 10000


x = np.random.normal(size=N)
y = np.random.normal(x)
s = 1.*(y>0)

df = pd.DataFrame({"X": x, "Y": y, "S": s})

# %%
import numpy as np

x = np.random.normal(size=10000)
y = np.random.normal(x * x)

# %%
from statsmodels.api import OLS


df['intercept'] = 1.

model = OLS(exog=df[['X', 'intercept']], endog=df['Y'])
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.505
# Model:                            OLS   Adj. R-squared:                  0.504
# Method:                 Least Squares   F-statistic:                 1.018e+04
# Date:                Tue, 13 Apr 2021   Prob (F-statistic):               0.00
# Time:                        19:50:43   Log-Likelihood:                -14112.
# No. Observations:               10000   AIC:                         2.823e+04
# Df Residuals:                    9998   BIC:                         2.824e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# X              1.0043      0.010    100.895      0.000       0.985       1.024
# intercept      0.0023      0.010      0.235      0.814      -0.017       0.022
# ==============================================================================
# Omnibus:                        0.024   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.988   Jarque-Bera (JB):                0.036
# Skew:                          -0.001   Prob(JB):                        0.982
# Kurtosis:                       2.991   Cond. No.                         1.01
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
df.plot(x='X', y='Y', kind='scatter', alpha=0.2)

# %%
from statsmodels.api import OLS


df['intercept'] = 1.

s = 1

model = OLS(exog=df[df.S==s][['X', 'intercept']], 
            endog=df[df.S==s]['Y'])
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.280
# Model:                            OLS   Adj. R-squared:                  0.280
# Method:                 Least Squares   F-statistic:                     1958.
# Date:                Tue, 13 Apr 2021   Prob (F-statistic):               0.00
# Time:                        19:51:07   Log-Likelihood:                -5546.4
# No. Observations:                5029   AIC:                         1.110e+04
# Df Residuals:                    5027   BIC:                         1.111e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# X              0.5545      0.013     44.255      0.000       0.530       0.579
# intercept      0.8111      0.013     64.755      0.000       0.787       0.836
# ==============================================================================
# Omnibus:                      330.834   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              403.272
# Skew:                           0.646   Prob(JB):                     2.70e-88
# Kurtosis:                       3.505   Cond. No.                         1.91
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
df[df.S == 1].plot(x='X', y='Y', kind='scatter', alpha=0.2)

# %%
df[df.S == 0].plot(x='X', y='Y', kind='scatter', alpha=0.2)

# %%
df['residual'] = np.nan
df.loc[df.S==s, 'residual'] = result.resid

# %%
df[df.S==1].plot(x='X', y='residual', kind='scatter', alpha=0.2)
